# %%
import xarray as xr
import pandas as pd
import numpy as np
import os

# %%
os.chdir('/g/data/vf71/la6889/ACEAS_legacy_app/')

# %%
ds = xr.open_zarr('data/mean_tot-exp-bio_all_regions_simask_1deg_1961-2010.zarr/')
ds
# Out:
# <xarray.Dataset> Size: 343kB
# Dimensions:  (lat: 38, lon: 372)
# Coordinates:
#   * lat      (lat) float64 304B -82.5 -81.5 -80.5 -79.5 ... -47.5 -46.5 -45.5
#   * lon      (lon) float64 3kB -81.5 -80.5 -79.5 -78.5 ... 287.5 288.5 289.5
# Data variables:
#     fao-48   (lat, lon) float64 113kB dask.array<chunksize=(38, 372), meta=np.ndarray>
#     fao-58   (lat, lon) float64 113kB dask.array<chunksize=(38, 372), meta=np.ndarray>
#     fao-88   (lat, lon) float64 113kB dask.array<chunksize=(38, 372), meta=np.ndarray>

# %%
df = ds.to_dataframe().dropna(how = 'all').reset_index()
df
# Out:
#        lat    lon     fao-48    fao-58    fao-88
# 0    -78.5  195.5        NaN       NaN  0.613878
# 1    -78.5  196.5        NaN       NaN  0.640605
# 2    -77.5  -49.5  11.236005       NaN       NaN
# 3    -77.5  -48.5  14.863361       NaN       NaN
# 4    -77.5  -47.5   9.797365       NaN       NaN
# ...    ...    ...        ...       ...       ...
# 5988 -45.5   75.5        NaN  0.236435       NaN
# 5989 -45.5   76.5        NaN  0.160827       NaN
# 5990 -45.5   77.5        NaN  0.169277       NaN
# 5991 -45.5   78.5        NaN  0.233896       NaN
# 5992 -45.5   79.5        NaN  0.348685       NaN
#
# [5993 rows x 5 columns]

# %%
df = pd.melt(df, id_vars = ['lat', 'lon'], value_vars = ['fao-48', 'fao-58', 'fao-88'],
        var_name = 'region', value_name = 'biomass').dropna()
df
# Out:
#         lat    lon  region    biomass
# 2     -77.5  -49.5  fao-48  11.236005
# 3     -77.5  -48.5  fao-48  14.863361
# 4     -77.5  -47.5  fao-48   9.797365
# 5     -77.5  -46.5  fao-48   9.207510
# 6     -77.5  -45.5  fao-48  10.278994
# ...     ...    ...     ...        ...
# 16076 -60.5  285.5  fao-88   0.032161
# 16077 -60.5  286.5  fao-88   0.029763
# 16078 -60.5  287.5  fao-88   0.043346
# 16079 -60.5  288.5  fao-88   0.045107
# 16080 -60.5  289.5  fao-88   0.046209
#
# [5993 rows x 4 columns]

# %%
df['tooltip'] = df.apply(lambda x:
                         f'Lon: {round(x.lon, 2)}°, Lat: {round(x.lat, 2)}°\nBiomass: {round(x.biomass, 2)} tonnes/km²\nRegion:{x.region}',
                         axis = 1)
df
# Out:
#         lat    lon  region    biomass  \
# 2     -77.5  -49.5  fao-48  11.236005
# 3     -77.5  -48.5  fao-48  14.863361
# 4     -77.5  -47.5  fao-48   9.797365
# 5     -77.5  -46.5  fao-48   9.207510
# 6     -77.5  -45.5  fao-48  10.278994
# ...     ...    ...     ...        ...
# 16076 -60.5  285.5  fao-88   0.032161
# 16077 -60.5  286.5  fao-88   0.029763
# 16078 -60.5  287.5  fao-88   0.043346
# 16079 -60.5  288.5  fao-88   0.045107
# 16080 -60.5  289.5  fao-88   0.046209
#
#                                                  tooltip
# 2      Lon: -49.5°, Lat: -77.5°\nBiomass: 11.24 tonne...
# 3      Lon: -48.5°, Lat: -77.5°\nBiomass: 14.86 tonne...
# 4      Lon: -47.5°, Lat: -77.5°\nBiomass: 9.8 tonnes/...
# 5      Lon: -46.5°, Lat: -77.5°\nBiomass: 9.21 tonnes...
# 6      Lon: -45.5°, Lat: -77.5°\nBiomass: 10.28 tonne...
# ...                                                  ...
# 16076  Lon: 285.5°, Lat: -60.5°\nBiomass: 0.03 tonnes...
# 16077  Lon: 286.5°, Lat: -60.5°\nBiomass: 0.03 tonnes...
# 16078  Lon: 287.5°, Lat: -60.5°\nBiomass: 0.04 tonnes...
# 16079  Lon: 288.5°, Lat: -60.5°\nBiomass: 0.05 tonnes...
# 16080  Lon: 289.5°, Lat: -60.5°\nBiomass: 0.05 tonnes...
#
# [5993 rows x 5 columns]

# %%
df.to_csv('data/test.csv', index = False)
